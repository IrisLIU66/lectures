# %% [markdown]
# # Week 2 session - Review: Python basics
#
# Useful documentation: [https://docs.python.org/3/library/index.html](https://docs.python.org/3/library/index.html)

# %% [markdown]
# ## Variable assignment
#
# What will be the output?

# %%
# Defining our variables
a = 4*2
b = a
a += 2 # a = a + 2

# Display the values of a and b
# print(): sep='输入隔开符'输出变量间的隔开符(默认' '空格符)
print(a, b, a+1, b+2, a+b) 
print(a, b, a+1, b+2, a+b, sep=', ') 
print(a, b, a+1, b+2, a+b, sep=' and then ') 
# 报错中的'^'符指出报错行从哪里开始出错
# Out:
# 10 8 11 10 18
# 10, 8, 11, 10, 18
# 10 and then 8 and then 11 and then 10 and then 18

# %% [markdown]
# ## Strings
#
# What will be the output?

# %%
name_A = 'Maariya'
name_B = 'Tommy'
name_C = 'Jia'

# max():如果输入字符串变量，返回首字母最大(字母表最往后)的变量
print(max(name_A, name_B, name_C))
# Out:
# Tommy

# %%
print(10 > 5)
print(10 < 5)
# Out:
# True
# False

# %%
print(name_A > name_B) #同样是比较首字母大小
# Out:
# False

# %%
print(name_B + name_C) #直接拼接
# Out:
# TommyJia

# %%
# Another way to print 10, 8
a = 10
b = 8

# '+'号只能同类型变量之间用 
print(str(a) + ',' + str(b))
print(f'{a}' + ',' + f'{b}')
# Out:
# 10,8
# 10,8

# %% [markdown]
# ## Formatted strings (f-strings)
#
# [Documentation on f-strings](https://docs.python.org/3/tutorial/inputoutput.html#formatted-string-literals)
#
# `Maariya's flatmates are Tommy and Jia.`

# %%
name_A = 'Maariya'
name_B = 'Tommy'
name_C = 'Jia'

# %%
# 如果有'符要输出，用""双引号来框住要输出的内容；
print(f"{name_A}'s flatmates are {name_B} and {name_C}")
# 也可以用\'直接输出单引号符 避免冲突
print(f'{name_A}\'s flatmates are {name_B} and {name_C}')
# Out:
# Maariya's flatmates are Tommy and Jia
# Maariya's flatmates are Tommy and Jia

# %%
# 这行是给上面提供思路的
print(f"{name_A}'s flatmates are...\n {name_B} and {name_C}") #内部可以加换行符
# Out:
# Maariya's flatmates are...
#  Tommy and Jia

# %% [markdown]
# `Room X is the largest.`

# %%
# Room areas in square metres
room_A, room_B, room_C = 6, 11.3, 8.2 #可以一起赋值
print(f'Room {max(room_A, room_B, room_C)} is the largest.')
# Out:
# Room 11.3 is the largest.

# %%
rooms = [room_A, room_B, room_C] # a list
print(rooms)
print(max(rooms))
# Out:
# [6, 11.3, 8.2]
# 11.3

# %% [markdown]
# `X's room is the largest.`

# %%
name_A = 'Maariya'
name_B = 'Tommy'
name_C = 'Jia'

# %%
print(rooms) # a list as define before
names = [name_A, name_B, name_C]
print(names) # a list
# Out:
# [6, 11.3, 8.2]
# ['Maariya', 'Tommy', 'Jia']

# %%
print(max(rooms))
# Out:
# 11.3

# %%
print(names[rooms.index(max(rooms))]) # name.index(x) 输出x这个元素在name这个list里面的位置(索引)

# %%
print(f"{names[rooms.index(max(rooms))]}'s room is the largest.")
# Out:
# Tommy's room is the largest.

# %%
# 这样分开写会更易读一些：
biggest_room_size = max(rooms)
biggest_room_position = rooms.index(biggest_room_size)
luckiest_flatmate = names[biggest_room_position]
print(f"{luckiest_flatmate}'s room is the largest.")
# Out:
# Tommy's room is the largest.
